# %% [markdown]
# <a href="https://colab.research.google.com/github/liz-lewis-manchester/CNM_2025_group_16/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import scipy as sp
df = pd.read_csv('initial_conditions.csv', encoding='latin1') #use encoding='latin1' because the symbol mu cannot be read
S = df[['Distance (m)']].values.flatten() #extract the data from each column into an array and use the flatten function to convert data into 1-dimensional
C = df[['Concentration (µg/m_ )']].values.flatten()
S_interpolate = np.arange(0,20,0.2) # Changed 0.2 to 101 to represent the number of samples for a 0.2 step size
C_interpolate = np.interp(S_interpolate, S, C)
print(S_interpolate)
print()
print(C_interpolate)
# Out:
# [ 0.   0.2  0.4  0.6  0.8  1.   1.2  1.4  1.6  1.8  2.   2.2  2.4  2.6
#   2.8  3.   3.2  3.4  3.6  3.8  4.   4.2  4.4  4.6  4.8  5.   5.2  5.4
#   5.6  5.8  6.   6.2  6.4  6.6  6.8  7.   7.2  7.4  7.6  7.8  8.   8.2
#   8.4  8.6  8.8  9.   9.2  9.4  9.6  9.8 10.  10.2 10.4 10.6 10.8 11.
#  11.2 11.4 11.6 11.8 12.  12.2 12.4 12.6 12.8 13.  13.2 13.4 13.6 13.8
#  14.  14.2 14.4 14.6 14.8 15.  15.2 15.4 15.6 15.8 16.  16.2 16.4 16.6
#  16.8 17.  17.2 17.4 17.6 17.8 18.  18.2 18.4 18.6 18.8 19.  19.2 19.4
#  19.6 19.8]
#
# [300.  242.  184.  126.   68.   10.   10.   10.   10.   10.   10.   10.
#   10.   10.   10.   10.   10.   10.   10.   10.   10.    9.6   9.2   8.8
#    8.4   8.    8.    8.    8.    8.    8.    8.    8.    8.    8.    8.
#    8.    8.    8.    8.    8.    7.8   7.6   7.4   7.2   7.    7.    7.
#    7.    7.    7.    7.    7.    7.    7.    7.   12.6  18.2  23.8  29.4
#   35.   39.4  43.8  48.2  52.6  57.   61.6  66.2  70.8  75.4  80.   81.
# ...
